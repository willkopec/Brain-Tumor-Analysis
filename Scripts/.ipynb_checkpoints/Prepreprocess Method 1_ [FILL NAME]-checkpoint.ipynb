# %%
####################################
# Connects to google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#########################
# Load Images : [Will Kopec] 
#
# Description of Preprocessing Method
# - 
# -
# -
#
#
# Loads in all the brain scans and crops them where the mask is
# Stores the data in Preprocessed_Data/[WillKopec] as a pickled dictionary with keys 1, 2, 3
# and the the corresponding values are all the 224 x 224 images stored as a numpy array in a list
# 
# 1 for meningioma, 2 for glioma, 3 for pituitary tumor

import h5py
import os
import numpy as np
import pickle

import scipy.io
from os import listdir
from os.path import isfile, join

import matplotlib.pyplot as plt

RAW_DATA_PATH = '/content/gdrive/MyDrive'
FEATURE_PATH = '/content/gdrive/MyDrive/CS 415 Project/WillKopec.pk1'
files = os.listdir(RAW_DATA_PATH)


print(files)
# Out:
# []
